# %%
import time
import random
import threading

#visuals
door_art = """
      ______
   ,-' ;  ! `-.
  / :  !  :  . \\
 |_ ;   __:  ;  |
 )| .  :)(.  !  |
 |"    (##)  _  |
 |  :  ;`'  (_) (
 |  :  :  .     |
 )_ !  ,  ;  ;  |
 || .  .  :  :  |
 |" .  |  :  .  |
 |____-----.____|
"""

key_art= """

               .--.
              /.-. '----------.
              \'-' .--"--""-"-'
               '--'
"""
clock_art= """

        _____
     _.'_____`._
   .'.-'  12 `-.`.
  /,' 11      1 `.\
 // 10      /   2 \\
;;         /       ::
|| 9  ----O      3 ||
::                 ;;
 \\ 8           4 //
  \`. 7       5 ,'/
   '.`-.__6__.-'.'
    ((-._____.-))
    _))       ((_
   '--'SSt    '--'
"""
skull_art= """


                            ,--.
                           {    }
                           K,   }
                          /  ~Y`
                     ,   /   /
                    {_'-K.__/
                      `/-.__L._
                      /  ' /`\_}
                     /  ' /
             ____   /  ' /
      ,-'~~~~    ~~/  ' /_
    ,'             ``~~~  ',
   (                        Y
  {                         I
 {      -                    `,
 |       ',                   )
 |        |   ,..__      __. Y
 |    .,_./  Y ' / ^Y   J   )|
 \           |' /   |   |   ||
  \          L_/    . _ (_,.'(
   \,   ,      ^^""' / |      )
     \_  \          /,L]     /
       '-_~-,       ` `   ./`
          `'{_            )
              ^^\..___,.--`
"""
# Exposition:
# Scene 1: Introduced to the characters and setting


print("Welcome to ESCAPE ROOM: Last Room Standing ")
user_name= input("Please enter your name: ")
def scene1():
    print("This year, after a grueling set of final exams, you and your group of friends decided to celebrate by visiting an escape room.")
    time.sleep(2)
    print("The group includes Sofia Ramirez, Henry Sullivan, Lily Cooper, Samuel Martinez, Silas Turner, and you, ready for an adventure.")
    time.sleep(2)
    print("Together, you make your way to the escape room, excited for a night of fun and mystery.")
    time.sleep(2)

    print("\nYou and your friends meet up at a local café to discuss the plan.")
    time.sleep(2)
    print("Sofia: 'I can’t believe we’re finally doing this! I’ve heard so much about this escape room.'")
    time.sleep(2)
    print("Henry: 'Yeah, it’s supposed to be one of the best in the state. I hope it’s not too scary though.'")
    time.sleep(2)
    print("Lily: 'Come on, Henry. A little fear makes it more exciting!'")
    time.sleep(2)
    print("Samuel: 'I’m ready for whatever they throw at us. Let’s do this!'")
    time.sleep(2)
    print("Silas: 'I’ve got a feeling this will be more challenging than we think.'")
    time.sleep(2)

    input("\nPress Enter to continue...")

# Scene 2: The escape room is located in Lynn Roseville.

def scene2():
    print("\nThe escape room is located in the eerie, historic district of Lynn Roseville, known for its old buildings and mysterious atmosphere.")
    time.sleep(2)
    print("You all meet up at the entrance, the anticipation palpable among the group.")
    time.sleep(2)
    print("As you step inside, the dim lighting and rustic decor add to the suspense.")
    time.sleep(2)
    print(door_art)
    time.sleep(2)
    print("\nThe entrance door creaks open, and you are greeted by a hostess who explains the basic rules.")
    time.sleep(2)
    print("Hostess: 'Welcome to our escape room. Please follow the safety guidelines and enjoy your experience. Now, let’s get started.'")
    time.sleep(2)

    input("\nPress Enter to continue...")
    time.sleep(2)

# Scene 3: Entering the first room and being introduced to the rules through a pre-recorded video.

def scene3():
    print("\nEntering the first room, you find yourselves in a forest-themed setting. The lights flicker ominously.")
    time.sleep(2)
    print("A pre-recorded video begins to play on a screen mounted on the wall. A voiceover explains the rules.")
    time.sleep(2)
    #add audio here
    print("'Welcome to the first room. In this room, you will have to complete an egg catcher game.")
    time.sleep(2)
    print("A series of eggs will be falling down, and you must catch 30 to move on to the next room.")
    time.sleep(2)
    print("If you do not complete this game in time, there will be severe consequences for everyone.'")
    time.sleep(2)

    print("\nSofia: 'This sounds like it will be easy. Let’s work together and catch those eggs.'")
    time.sleep(2)
    print("Henry: 'I’ll try not to drop any. This is going to be intense.'")
    time.sleep(2)
    print("Silas: 'I’ll keep an eye out for any patterns in how they drop.'")
    time.sleep(2)
    print(f"Lily: How do you feel, {user_name}?")
    input("A. 'Absolutely terrified! \nB. Ready for an adventure! \nC. I've been waiting for a thrill! \nD. I want to go home  \n")
    time.sleep(2)
    print("Sofia: Haha!")
    time.sleep(2)

input("\nPress Enter to start the game...")
time.sleep(2)

# Scene 4: (First game is introduced) Egg catcher game

def scene4():
    print("\nYou look around and see a basket and a mechanism set up to drop eggs from above.")
    time.sleep(2)
    print("The forest-themed room makes you feel like you're in an enchanted woodland.")
    time.sleep(2)
    print("The lights flicker again, adding to the tension. The game is about to start.")
    time.sleep(2)
    print("You need to catch 30 eggs to move on. If you don't, something terrible might happen.")
    time.sleep(2)

    print("\nThe game begins, and you focus intently on catching the falling eggs.")
    # Add egg-catching game here

    success = True  # Example result of the game
    if success:
        print("\nYou successfully catch all the eggs and move on to the next room.")
        print("???: 'Hmm, that's not fun...")
        time.sleep(2)
        print("The lights suddenly go out, and you hear a chilling sound.")
        time.sleep(2)
        print("Sofia: 'What's happening? I can't see anything!! I thought we won!?!'")
        time.sleep(2)
        print("You hear Henry's voice screaming in the darkness.")
        time.sleep(2)
        print("Samuel: 'Henry?! Where are you?!'")
        time.sleep(2)
        print("The lights flicker back on, and you see Henry lying on the floor, motionless.")
        time.sleep(2)
        print("Lily: 'No! Henry! Please, wake up!'")
        time.sleep(2)
        print("Silas: 'This is bad. We need to get out of here, now!'")
        time.sleep(2)
        print("You all realize the severity of the situation and decide to move forward, more determined than ever to escape this nightmare.")
        time.sleep(2)
    else:
        print("\nYou fail to catch enough eggs. The room fills with an ominous sound, and you fear the consequences.")
        time.sleep(2)
        print("???: 'You failed the challenge. Now, face the consequences.'")
        time.sleep(2)
        print("The lights suddenly go out, and you hear a chilling sound.")
        time.sleep(2)
        print("Sofia: 'What's happening? I can't see anything!!'")
        time.sleep(2)
        print("You hear Henry's voice screaming in the darkness.")
        time.sleep(2)
        print("Samuel: 'Henry?! Where are you?!'")
        time.sleep(2)
        print("The lights flicker back on, and you see Henry lying on the floor, motionless.")
        time.sleep(2)
        print("Lily: 'No! Henry! Please, wake up!'")
        time.sleep(2)
        print("Silas: 'This is bad. We need to get out of here, now!'")
        time.sleep(2)
        print("You all realize the severity of the situation and decide to move forward, more determined than ever to escape this nightmare.")

    input("\nPress Enter to continue...")

# Rising Action:
# Scene 5: They advance into the next room and they are left without a clue on what to do.

def scene5():
    print("\nAfter successfully catching the eggs, the door to the next room opens. You all move forward.")
    time.sleep(2)
    print("The new room is dark and bare, with no obvious clues on what to do next.")
    time.sleep(2)
    print("You and your friends start investigating different items in the room, searching for hints.")
    time.sleep(2)
    print("You look in three different places, examining every detail, but nothing stands out.")
    time.sleep(2)

    print("\nSofia: 'There’s got to be something here. Let’s keep looking.'")
    time.sleep(2)
    print("Silas: 'Maybe there’s a hidden switch or something.'")
    time.sleep(2)
    print("Lily: 'I’ll check this corner, you guys look over there.'")
    time.sleep(2)
    print("Samuel: 'Don’t miss anything. Even the smallest detail could be important.'")
    time.sleep(2)
    print("Silas: 'Wait, What about the walls? Sometimes there are hidden panels or messages.'")
    time.sleep(2)

    input("\nPress Enter to continue...")
    time.sleep(2)
# Scene 6: Discovering the clue behind the peeling paint

def scene6():
    print("\nFrustration mounts as you run out of ideas. Then, you notice something odd about the paint on one of the walls.")
    time.sleep(2)
    print("It seems to be peeling away in a particular spot. Could this be a clue?")
    time.sleep(2)
    #chat gpt assited with action this allows you to define your list or line one after the other
    action = input("Do you want to peel the paint off the wall? (yes/no): ").strip().lower()
    time.sleep(2)
    while action not in ["yes", "no"]:
        action = input("Invalid input. Do you want to peel the paint off the wall? (yes/no): ").strip().lower()
        time.sleep(2)
    if action == "yes":
        print("\nYou carefully peel the paint off the wall, revealing a hidden message. It's the next game: Hangman.")
        time.sleep(2)
        print("\nSofia: 'Great find! Let’s figure out this next puzzle.'")
        time.sleep(2)
        print("Henry: 'Hangman? I used to play this all the time. We can do this.'")
        time.sleep(2)
        print("Lily: 'Finally, a clue. Let’s get started.'")
        time.sleep(2)
        print("Samuel: 'We need to be smart about this. No mistakes.'")
        time.sleep(2)
        play_hangman()
    else:
        print("Samuel: 'We've been searching for too long let's just try the wall again")
        time.sleep(2)
        print("Henry: 'I agree, what's there to lose?'")
        time.sleep(2)
        print("You peel it off and discover the hidden message: the next game is Hangman.")
        time.sleep(2)
        print("\nSofia: 'Great find! Let’s figure out this next puzzle.'")
        time.sleep(2)
        print("Henry: 'Hangman? I used to play this all the time. We can do this.'")
        time.sleep(2)
        print("Lily: 'Finally, a clue. Let’s get started.'")
        time.sleep(2)
        print("Samuel: 'We need to be smart about this. No mistakes.'")
        time.sleep(2)
        play_hangman()
    input("\nPress Enter to continue...")
    time.sleep(2)

def play_hangman():
  #intructions explained
    print('''\nWelcome to Hangman! A word will be chosen at random and you must try to guess the word correctly letter by letter before you run out of attempts. Good luck!''')
   #words the the computer would randomly pick for the user to guess words from this list
    words = ["hangman", "chairs", "backpack"
     , "clothing", "computer", "python", "program", "glasses", "sweatshirt", "sweatpants", "mattress", "friends", "clocks", "biology", "algebra", "suitcase", "knives", "ninjas", "shampoo"]
   #computer chooses random
    chosen_word = random.choice(words).lower()
    player_guess = None  # will hold the players guess
    guessed_letters = []  # a list of letters guessed so far
    word_guessed = ["-"] * len(chosen_word)  # create an unguessed, blank version of the word
    joined_word = None  # joins the words in the list word_guessed

    HANGMAN = (
      """
        -----
        |   |
        |
        |
        |
        |
        |
        |
        |
        --------
        """,
        """
        -----
        |   |
        |   0
        |
        |
        |
        |
        |
        |
        --------
        """,
        """
        -----
        |   |
        |   0
        |  -+-
        |
        |
        |
        |
        |
        --------
        """,
        """
        -----
        |   |
        |   0
        | /-+-
        |
        |
        |
        |
        |
        --------
        """,
        """
        -----
        |   |
        |   0
        | /-+-\\
        |
        |
        |
        |
        |
        --------
        """,
        """
        -----
        |   |
        |   0
        | /-+-\\
        |   |
        |
        |
        |
        |
        --------
        """,
        """
        -----
        |   |
        |   0
        | /-+-\\
        |   |
        |   |
        |  |
        |
        |
        --------
        """,
        """
        -----
        |   |
        |   0
        | /-+-\\
        |   |
        |   |
        |  | |
        |
        |
        --------
        """,
        """
        -----
        |   |
        |   0
        | /-+-\\
        |   |
        |   |
        |  | |
        |  |
        |
        --------
        """,
        """
        -----
        |   |
        |   0
        | /-+-\\
        |   |
        |   |
        |  | |
        |  | |
        |
        --------
        """
    )
    print(HANGMAN[0])
    attempts = len(HANGMAN) - 1

    while attempts != 0 and "-" in word_guessed: #chatgpt
        print("\n") #chatgpt
        player_guess = input("Guess a letter: ").lower() # this allows the user to guess one letter each round

        if len(player_guess) > 1: # this is in case the user desides to put more than 1 letter at a time
            print("You can only guess a single letter!")
            continue
        elif player_guess == "":
            print("You didn't guess a letter!") # this is just if the user doesnt put anything in or puts something other than a letter
            continue
        elif player_guess in guessed_letters: # this is so the user doesnt lose a turn of they guess a letter twice
            print("You already guessed that letter!")
            continue
        elif player_guess not in "abcdefghijklmnopqrstuvwxyz":
            print("You can only guess letters!")
            continue

        guessed_letters.append(player_guess)

        for letter in range(len(chosen_word)): #chatgpt
            if player_guess == chosen_word[letter]:
                word_guessed[letter] = player_guess

        if player_guess not in chosen_word: # chatgpt
            attempts -= 1
            print(HANGMAN[(len(HANGMAN) - 1) - attempts])

        joined_word = "".join(word_guessed)
        print("Your word: ", joined_word)
        print("Attempts left: ", attempts)

    if "-" not in word_guessed:
        print("Congratulations! You guessed the word correctly!")
        time.sleep(2)
        print("Silas: 'We did it!'")
        time.sleep(2)
        print("Lily: 'Finally, it took way to long.")
        time.sleep(2)
        print("???: 'Hahahah You think just because you guessed a few letters you think you're free?")
        time.sleep(2)
        print("Suddenly,the lights went out and shuffling sounds echoed throughout the room")
        time.sleep(2)
        print("Sofia: 'What's happening? I can't see anything!!'")
        time.sleep(2)
        print("The lights turn back on and you all look around the room confused.")
        time.sleep(2)
        print("Samuel: 'Uhh, guys...Where's Silas?'")
        time.sleep(2)
        print("Sofia: 'No idea... I'm worried'")
        time.sleep(2)
        print("Lily: 'I guess we left him hanging'")
        time.sleep(2)
        print("Sofia: 'Lily, that's not funny what if something happened!'")
        time.sleep(2)
        print("Samuel: 'First Henry now Silas.. something's not right with this escape room'")
        time.sleep(2)
        print(" Lily: 'Let's just keep moving to the next room maybe they're in there.'")
        time.sleep(2)
    else:
        print("Unlucky! You ran out of attempts. The word was {}.".format(chosen_word)) #helps create formatted strings
        print("Silas:'Damn, we failed.. what's the punishment?'")
        print("Suddenly,the lights went out and shuffling sounds echoed throughout the room")
        time.sleep(2)
        print("Sofia: 'What's happening? I can't see anything!!'")
        time.sleep(2)
        print("The lights turn back on and you all look around the room confused.")
        time.sleep(2)
        print("Samuel:'Uhh, guys...Where's Silas?'")
        time.sleep(2)
        print("Sofia:'No idea... I'm worried'")
        time.sleep(2)
        print("Lily:'I guess we left him hanging'")
        time.sleep(2)
        print("Sofia:'Lily, that's not funny what if something happened!'")
        time.sleep(2)
        print("Samuel:'First Henry now Silas.. something's not right with this escape room'")
        time.sleep(2)
        print(" Lily:'Let's just keep moving to the next room maybe they're in there.'")
        time.sleep(2)

def choice_scene():
    print("\nA. 'Maybe we should look around for them more...'")
    time.sleep(2)
    print("B. 'I agree with Lily, let's continue.'")
    time.sleep(2)

    choice = input("\nChoose A or B: ").strip().upper()
    time.sleep(2)
    if choice == 'A':
        print("\nYou decide to look around for them more. You search the area meticulously, hoping to find any clues or signs of your missing friends.")
        time.sleep(2)
        print("As you move slowly and cautiously through the room, you notice several objects and potential hiding spots.")
        time.sleep(2)
        print("\nFirst, you examine a dusty bookshelf filled with old, worn-out books. You carefully pull each book, checking for any hidden compartments.")
        time.sleep(2)
        print("After a few moments, you find a loose brick behind the bookshelf. Removing the brick,you discover something")
        time.sleep(2)
        print("Sophia:'Ew!! Is that a skull?'")
        time.sleep(2)
        print(skull_art)
        time.sleep(2)
        print("Henry:'Dude that's nasty..let's just continue to the next room'")
        time.sleep(2)
        print("Sofia:'I'm scared..I agree, maybe they all ditched us and are waiting outside!'")
        time.sleep(2)
        scene7()
    elif choice == 'B':
        print("\nYou agree with Lily and decide to continue your quest. The path ahead is uncertain and the issue is slowly turning into life, but you stick together and move forward.")
        time.sleep(2)
        scene7()
    else:
        print("\nInvalid choice. Please choose A or B.")
        time.sleep(2)
        choice_scene()  # Retry if the input is invalid

# Scene 7: Finding the key to escape

import time

def scene7():
    print("\nYou all step into the next room, which seems to be a storage area filled with old furniture and scattered objects.")
    time.sleep(2)
    print("The door slams shut behind you, and a digital timer on the wall starts counting down from 5 minutes.")
    time.sleep(2)
    print("Suddenly, water begins to trickle into the room from small openings in the walls.")
    time.sleep(2)
    print("\nSofia: We need to find the key to that door! Quickly!")
    time.sleep(2)
    print("\nEveryone starts frantically searching the room. You have to find the correct key before the room fills with water.")
    time.sleep(2)

    # Start the timer
    start_time = time.time()
    time_limit = 5 * 60  # 5 minutes in seconds

    keys_found = 0
    correct_key_found = False

    for i in range(5): #used chatgpt to work the loop since we ran into multiple issues
        elapsed_time = time.time() - start_time #this  is to keep track of the time used by the user
        if elapsed_time > time_limit:
            print("\nThe timer hits zero. The water rises too high, and you all struggle to stay afloat.")
            time.sleep(2)
            print("\nThe room fills with water, and you all meet a tragic end.")
            time.sleep(2)
            return False  # End the game if time runs out

        if not correct_key_found:
            search_spot = input(f"Choose a spot to search for key {i + 1} \nA.under the chair \nB.inside the drawer \nC.in the vase \nD.under the rug \nE.behind the painting \n(Please enter A, B, C, D, or E) ").strip().lower()
            if search_spot in ["(A) Under the chair", "(B) Inside the drawer", "(C) In the vase", "(D) Under the rug", "(E) Behind the painting"]:
                keys_found += 1
                print(f"\nYou found a key in the {search_spot}!")
                time.sleep(2)
                print(key_art)
                if keys_found == 3:  # Assume the correct key is the third one found
                    correct_key_found = True
                    print("\nThis key looks different. It might be the one!")
                    time.sleep(2)
                else:
                    print("\nThis key doesn't fit. Keep searching!")
                    time.sleep(2)
            else:
                print("\nThere's nothing here. Keep searching!")
                time.sleep(2)

    if correct_key_found:
        print("\nYou rush to the door and try the key. It fits! You turn the key, and the door unlocks.")
        time.sleep(2)
        print("\nEveryone scrambles through the door, escaping the rising water just in time.")
        time.sleep(2)
        return True  # Indicating they successfully escaped
    else:
        print("\nThe water rises too high, and you all struggle to stay afloat.")
        time.sleep(2)
        print("\nThe room fills with water, and you all meet a tragic end.")
        time.sleep(2)
        return False  # Indicating the end of the game if they fail

# Scene 8: Lily tries to kill the user

def scene8():
    print("\nThe exit leads to a narrow ladder that ascends to the next level.")
    time.sleep(2)
    print("You start climbing the ladder, with Lily just behind you.")
    time.sleep(2)
    print("\nAs you climb, you feel a sharp pull on your leg. It's Lily, trying to pull you off the ladder!")
    time.sleep(2)
    print("Lily: 'You think you’re so smart, don’t you? I won’t let you win!'")
    time.sleep(2)

    action = input("Do you want to fight back or try to reason with Lily? (fight/reason): ").strip().lower()
    time.sleep(2)

    while action not in ["fight", "reason"]:
        action = input("Invalid input. Do you want to fight back or try to reason with Lily? (fight/reason): ").strip().lower()
        time.sleep(2)

    if action == "fight":
        print("\nYou kick your leg free and climb faster. Lily loses her grip and falls a few rungs down the ladder.")
        time.sleep(2)
        print("You manage to reach the top, panting and shaken.")
        time.sleep(2)
        print("Lily glares at you, but she continues climbing without further incident.")
        time.sleep(2)
    else:
        print("\nYou try to reason with Lily, but she is too consumed by her fear and jealousy.")
        time.sleep(2)
        print("Lily: 'There’s no reasoning here. It’s survival of the fittest!'")
        time.sleep(2)
        print("You manage to dodge her attempts and climb faster, reaching the top before she can pull you down.")
        time.sleep(2)
        print("Lily eventually climbs up, still glaring at you, but she doesn't try to attack again.")
        time.sleep(2)

    input("\nPress Enter to continue...")
    time.sleep(2)

# Scene 9: The group is exhausted and shaken

def scene9():
    print("\nThe group reaches the next room, exhausted and shaken from the previous ordeal.")
    time.sleep(2)
    print("The walls are damp, and the sound of dripping water echoes in the space.")
    time.sleep(2)
    print("Everyone is relieved to have made it past, but the atmosphere is tense.")
    time.sleep(2)
    print("Distrust and worry are evident in everyone's eyes.")
    time.sleep(2)
    print("\nSofia: 'We can't keep going like this. We need to stick together.'")
    time.sleep(2)
    print("Samuel: 'But how can we trust each other after what just happened?'")
    time.sleep(2)
    print("Lily: 'I... I'm sorry. I don't know what came over me.'")
    time.sleep(2)
    print("Samuel: 'We don't have time for this. Let's focus on getting out of here.'")
    time.sleep(2)
    print("Sofia: 'Agreed. We need to stay sharp and watch each other's backs.'")
    time.sleep(2)

    input("\nPress Enter to continue...") #to continue the scene using space bar or enter
    time.sleep(2)

# Scene 10: The maze and the monster

def scene10():
    print("\nThe group of friends enters the next room, hoping it’s the end of the escape room.")
    time.sleep(2)
    print("They open the next door, only to see a long hallway with no end in sight.")
    time.sleep(2)
    print("They start walking and soon reach the end of the hallway, where a wall with instructions awaits.")
    time.sleep(2)
    print("\nThe wall reads: 'Complete this maze before the monster catches you, and you will be free.'")
    time.sleep(2)
    print("The friends look hopeful, thinking this might be the last step.")
    time.sleep(2)
    print("\nSofia: 'We need to move, now!'") #\n is used frequently in the code and it makes the code print out in a new line which is essential for visually pleasing reading which is a major aspect of our game
    time.sleep(2)
    print("Lily: 'I won’t let us fail. Not again.'")
    time.sleep(2)
    print("Samuel: 'Run! We don't have time to waste!'")
    time.sleep(2)

def scene11():
    print("You and your friends proceed cautiously, unsure of what lies ahead.")
    time.sleep(2)
    print("Suddenly, a growling sound reverberates through the hallway, and you all freeze.")
    time.sleep(2)
    print("Out of the shadows, a monstrous dog emerges, its eyes glowing and blades affixed to its limbs.")
    time.sleep(2)
    print(f"{user_name}: 'It's a dog! But something's wrong with it...'")
    time.sleep(2)
    print("Despite its somewhat friendly appearance, you cautiously approach to pet it.")
    time.sleep(2)
    print("In an instant, the dog snaps, nearly biting off your pinky. Panic ensues as you all scatter through the maze, desperately searching for an escape while the dog, now equipped with blades, chases you.")
    time.sleep(2)
    print(f"Inch by inch, it closes in on {user_name}, who finds themselves trapped in a corner.")
    time.sleep(2)
    print(f"Suddenly, a scream echoes—it's {random.choice(['Sofia', 'Lily', 'Samuel'])}, luring the dog away so {user_name} can run.")
    time.sleep(2)
    print(f"Then, they hear {random.choice(['Sofia', 'Lily', 'Samuel'])} shout, 'We found the way out!' as they explain the exit route.")
    time.sleep(2)
    input("\nPress Enter to continue...")
    time.sleep(2)


#add maze game here
def scene12():
    print("\nYou and your friends manage to find the exit of the maze, but you notice that Lily is still inside.")
    time.sleep(2)
    print(f"{user_name}: 'Lily is still in there! We can't leave without her!'")
    time.sleep(2)
    print("Your friends look at each other, uncertainty and fear etched on their faces.")
    time.sleep(2)
    print("\nYou are given a choice:")
    time.sleep(2)
    choice = input("Do you want to stay and help Lily escape or escape by yourself? (help/escape): ").strip().lower()
    time.sleep(2)
    while choice not in ["help", "escape"]:
        choice = input("Invalid input. Do you want to stay and help Lily escape or escape by yourself? (help/escape): ").strip().lower()
        time.sleep(2)

    if choice == "help":
        print(f"\n{user_name} decides to go back and help Lily. You navigate through the maze, calling out her name.")
        time.sleep(2)
        print("You find Lily cornered by the monstrous dog, and you distract it, allowing Lily to escape.")
        time.sleep(2)
        print("As Lily runs towards the exit, the dog turns its attention back to you.")
        time.sleep(2)
        print(f"In a heroic but tragic moment, {user_name} sacrifices themselves, ensuring Lily's safety.")
        time.sleep(2)
        print("Your friends hear your screams and realize what has happened. They make it out of the escape room, forever grateful for your bravery.")
        time.sleep(2)
        print("\nGAME OVER. You sacrificed yourself to save your friend.")
        time.sleep(2)
    else:
        print(f"\n{user_name} makes the tough decision to escape by themselves, ensuring their own safety.")
        time.sleep(2)
        print("You run towards the exit, glancing back one last time, hoping Lily will make it out too.")
        time.sleep(2)
        print("As you burst through the exit, you hear the sounds of your friends celebrating your escape.")
        time.sleep(2)
        print("The authorities are called, and the escape room is shut down for investigation.")
        time.sleep(2)
        print("You and your friends are safe, but the memory of Lily lingers on your mind.")
        time.sleep(2)
        print("\nGAME OVER. You escaped, but at what cost?")


    # Simulate running through the maze and avoiding the monster
    success = True  # Example result of the maze challenge
    if success:
        print("You emerge into the daylight, exhausted but victorious.")
        time.sleep(2)
        print("Congratulations! You have successfully completed the escape room.")
        time.sleep(2)
        print("Or did you..")
        time.sleep
    else:
        print("\nThe monster catches up to you before you can find the exit.")
        time.sleep(2)
        print("You all meet a tragic end, unable to escape the maze in time.")
        time.sleep(2)

    input("\nPress Enter to end the game...")
    time.sleep(2)

# Main Game Flow
def main():
    scene1()
    scene2()
    scene3()
    scene4()
    scene5()
    scene6()
    choice_scene()
    if scene7():
        scene8()
        scene9()
        scene10()
        scene11()
        scene12()
if __name__ == "__main__":
    main()
# Out:
# Welcome to ESCAPE ROOM: Last Room Standing
# Please enter your name: fj
#
# Press Enter to start the game...
# This year, after a grueling set of final exams, you and your group of friends decided to celebrate by visiting an escape room.
# The group includes Sofia Ramirez, Henry Sullivan, Lily Cooper, Samuel Martinez, Silas Turner, and you, ready for an adventure.
# Together, you make your way to the escape room, excited for a night of fun and mystery.
#
# You and your friends meet up at a local café to discuss the plan.
# Sofia: 'I can’t believe we’re finally doing this! I’ve heard so much about this escape room.'
# Henry: 'Yeah, it’s supposed to be one of the best in the state. I hope it’s not too scary though.'
# Lily: 'Come on, Henry. A little fear makes it more exciting!'
# Samuel: 'I’m ready for whatever they throw at us. Let’s do this!'
# Silas: 'I’ve got a feeling this will be more challenging than we think.'
#
# Press Enter to continue...
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ca09cb23fb2a> in <cell line: 1>()
# ----> 1 gv
#       2
#
# NameError: name 'gv' is not defined
